# %%
##%matplotlib inline


import matplotlib.pyplot as plt

import time
from scipy import rand

# %%
from scipy import rand

# %%
# %matplotlib notebook
fig ,ax = plt.subplots()
for f in range(5):
    b = rand(10, 10) * 2
    ax.pcolormesh(b)
    fig.canvas.draw()
    time.sleep(1)
# Out:
# <img src="data:image/png;base64,...">
